# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from sklearn import preprocessing

# %%
financial_data = pd.read_excel('../Given_Data/NBA_financial_data.xlsx')
financial_data = financial_data.drop(columns= ['Arena Sponsor', 'Jersey Sponsor'])
financial_data
# Out:
#               City           State               Team Name  \
# 0          Atlanta         Georgia           Atlanta Hawks
# 1           Boston   Massachusetts          Boston Celtics
# 2         Brooklyn        New York           Brooklyn Nets
# 3        Charlotte  North Carolina       Charlotte Hornets
# 4          Chicago        Illinois           Chicago Bulls
# 5        Cleveland            Ohio     Cleveland Cavaliers
# 6           Dallas           Texas        Dallas Mavericks
# 7           Denver        Colorado          Denver Nuggets
# 8          Detroit        Michigan         Detroit Pistons
# 9     San Franciso      California   Golden State Warriors
# 10         Houston           Texas         Houston Rockets
# 11   Indianapolis          Indiana          Indiana Pacers
# 12     Los Angeles      California    Los Angeles Clippers
# 13     Los Angeles      California      Los Angeles Lakers
# 14         Memphis       Tennessee       Memphis Grizzlies
# ...

# %%
#dropped city ascii, city_alt, county_flips, lat and long, incorporated, timezone
city_data_raw =pd.read_excel('../Given_Data/us_city_data.xlsx')
city_data = city_data_raw.drop(columns= ['city_ascii', 'city_alt', 'county_fips','county_fips_all','lat','lng','incorporated','timezone'])
city_data.head()
# Out:
#           city state_id  state_name  county_name  \
# 0     New York       NY    New York       Queens
# 1  Los Angeles       CA  California  Los Angeles
# 2      Chicago       IL    Illinois         Cook
# 3        Miami       FL     Florida   Miami-Dade
# 4      Houston       TX       Texas       Harris
#
#                         county_name_all  population  population_proper  \
# 0  Queens|Kings|Richmond|Bronx|New York  18908608.0          8622467.0
# 1                           Los Angeles  11922389.0          3881041.0
# 2                           Cook|DuPage   8497759.0          2721914.0
# 3                            Miami-Dade   6080145.0           443665.0
# 4           Harris|Fort Bend|Montgomery   5970127.0          2296253.0
#
#    density source  military  ...  poverty  limited_english  commute_time  \
# 0  11080.3  shape     False  ...     17.2             13.9          41.1
# 1   3184.7  shape     False  ...     16.6             13.7          31.3
# ...

# %%
city_data = city_data.drop(columns = ['zips', 'source', 'cbsa_fips', 'csa_fips'])
city_data
# Out:
#                 city state_id    state_name   county_name  \
# 0           New York       NY      New York        Queens
# 1        Los Angeles       CA    California   Los Angeles
# 2            Chicago       IL      Illinois          Cook
# 3              Miami       FL       Florida    Miami-Dade
# 4            Houston       TX         Texas        Harris
# ...              ...      ...           ...           ...
# 109034      Pennwood       DE      Delaware          Kent
# 109035       Buckton       NY      New York  St. Lawrence
# 109036   Millerstown       PA  Pennsylvania         Blair
# 109037  Hidden Lakes       OH          Ohio        Morrow
# 109038      Bancroft       ME         Maine     Aroostook
#
#                              county_name_all  population  population_proper  \
# 0       Queens|Kings|Richmond|Bronx|New York  18908608.0          8622467.0
# 1                                Los Angeles  11922389.0          3881041.0
# ...

# %%
columns_mapping = {'population': 'urbanPopulation', 'population_proper': 'municipalPopulation', 'ranking': 'importance_Ranking'}
city_data.rename(columns=columns_mapping, inplace=True)
city_data
# Out:
#                 city state_id    state_name   county_name  \
# 0           New York       NY      New York        Queens
# 1        Los Angeles       CA    California   Los Angeles
# 2            Chicago       IL      Illinois          Cook
# 3              Miami       FL       Florida    Miami-Dade
# 4            Houston       TX         Texas        Harris
# ...              ...      ...           ...           ...
# 109034      Pennwood       DE      Delaware          Kent
# 109035       Buckton       NY      New York  St. Lawrence
# 109036   Millerstown       PA  Pennsylvania         Blair
# 109037  Hidden Lakes       OH          Ohio        Morrow
# 109038      Bancroft       ME         Maine     Aroostook
#
#                              county_name_all  urbanPopulation  \
# 0       Queens|Kings|Richmond|Bronx|New York       18908608.0
# 1                                Los Angeles       11922389.0
# 2                                Cook|DuPage        8497759.0
# ...

# %%
country_data_raw = pd.read_excel('../Given_Data/world_country_data.xlsx')
country_data_raw = country_data_raw.drop(columns = ['Latitude','Longitude','Calling Code'])
columns_mapping = {'Density\n(P/Km2)': 'Density'}
country_data_raw.rename(columns = columns_mapping, inplace = True)
country_data_raw
# Out:
#          Country  Density Abbreviation  Agricultural Land( %)  Land Area(Km2)  \
# 0    Afghanistan       60           AF                  0.581        652230.0
# 1        Albania      105           AL                  0.431         28748.0
# 2        Algeria       18           DZ                  0.174       2381741.0
# 3        Andorra      164           AD                  0.400           468.0
# 4         Angola       26           AO                  0.475       1246700.0
# ..           ...      ...          ...                    ...             ...
# 190    Venezuela       32           VE                  0.245        912050.0
# 191      Vietnam      314           VN                  0.393        331210.0
# 192        Yemen       56           YE                  0.446        527968.0
# 193       Zambia       25           ZM                  0.321        752618.0
# 194     Zimbabwe       38           ZW                  0.419        390757.0
#
# ...

# %%
csv_file_path = "../Cleaned_Data/Clean_NBA_Financial_Data"
financial_data.to_csv(csv_file_path, index = False)
csv_file_path = "../Cleaned_Data/Clean_US_City_Data"
city_data.
