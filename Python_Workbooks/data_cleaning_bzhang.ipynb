# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Read in Data
#
# * Financial Data (2022/2023 NBA season)
# * City Data
# * World Data

# %%
financials = pd.read_excel('Given_Data/NBA_financial_data.xlsx')    #
cities = pd.read_excel('Given_Data/us_city_data.xlsx', nrows=500)   # grab first 500 rows

display(financials.head(30))
# display(cities.head())
# display(cities.describe())
#display(financials.describe())
# Out:
#               City           State               Team Name  \
# 0          Atlanta         Georgia           Atlanta Hawks
# 1           Boston   Massachusetts          Boston Celtics
# 2         Brooklyn        New York           Brooklyn Nets
# 3        Charlotte  North Carolina       Charlotte Hornets
# 4          Chicago        Illinois           Chicago Bulls
# 5        Cleveland            Ohio     Cleveland Cavaliers
# 6           Dallas           Texas        Dallas Mavericks
# 7           Denver        Colorado          Denver Nuggets
# 8          Detroit        Michigan         Detroit Pistons
# 9    San Francisco      California   Golden State Warriors
# 10         Houston           Texas         Houston Rockets
# 11    Indianapolis         Indiana          Indiana Pacers
# 12     Los Angeles      California    Los Angeles Clippers
# 13     Los Angeles      California      Los Angeles Lakers
# 14         Memphis       Tennessee       Memphis Grizzlies
# 15           Miami         Florida              Miami Heat
# 16       Milwaukee       Wisconsin         Milwaukee Bucks
# 17     Minneapolis       Minnesota  Minnesota Timberwolves
# 18     New Orleans       Louisiana    New Orleans Pelicans
# 19        New York        New York         New York Knicks
# 20   Oklahoma City        Oklahoma   Oklahoma City Thunder
# 21         Orlando         Florida           Orlando Magic
# 22    Philadelphia    Pennsylvania      Philadelphia 76ers
# 23         Phoenix         Arizona            Phoenix Suns
# 24        Portland          Oregon  Portland Trail Blazers
# 25      Sacramento      California        Sacramento Kings
# 26     San Antonio           Texas       San Antonio Spurs
# 27         Toronto          Canada         Toronto Raptors
# 28  Salt Lake City            Utah               Utah Jazz
# 29   Washington DC   Washington DC      Washington Wizards
#
#             Arena Sponsor  Arena Cost (millions)  Year of Arena Construction  \
# 0              State Farm                  213.5                        1999
# 1                 TD Bank                  160.0                        1995
# 2           Barclays Bank                 1000.0                        2012
# 3                Spectrum                  260.0                        2005
# 4         United Airlines                  175.0                        1994
# 5         Rocket Mortgage                  100.0                        1994
# 6       American Airlines                  420.0                        2001
# 7               Ball Corp                  187.0                        1999
# 8          Little Caesers                  862.9                        2017
# 9          JPMorgan Chase                 1400.0                        2019
# 10                 Toyota                  235.0                        2003
# 11             Gainbridge                  183.0                        1999
# 12             Crypto.com                  375.0                        1999
# 13             Crypto.com                  375.0                        1999
# 14                  FedEx                  250.0                        2004
# 15                 Kaseya                  213.0                        1999
# 16                 Fiserv                 1200.0                        2018
# 17                 Target                  104.0                        1990
# 18          Smoothie King                  114.0                        1999
# 19         JPMorgan Chase                  123.0                        1968
# 20                 Paycom                   89.2                        2002
# 21            Kia America                  480.0                        2010
# 22            Wells Fargo                  210.0                        1996
# 23              Footprint                   89.0                        1992
# 24            Moda Health                  262.0                        1995
# 25  Golden 1 Credit Union                  558.2                        2016
# 26             Frost Bank                  186.0                        2002
# 27             Scotiabank                  288.0                        1999
# 28         Delta Airlines                   93.0                        1991
# 29            Captial One                  260.0                        1997
#
#     Arena Capacity                        Jersey Sponsor  \
# 0            16600                                  YMCA
# 1            19156                            Vistaprint
# 2            17732                                Webull
# 3            19077                            Feastables
# 4            20917                              Motorola
# 5            19432                  Clevland-Cliffs Inc.
# 6            19200                                 Chime
# 7            19520                                Ibotta
# 8            20332             United Wholesale Mortgage
# 9            18064                               Rakuten
# 10           18055                          Credit Karma
# 11           17923                             Spokenote
# 12           19068                                   NaN
# 13           18997                                Bibigo
# 14           17794                                   NaN
# 15           19600                  Carnival Cruise Line
# 16           17500                              Motorola
# 17           18978                                  Aura
# 18           16867                                Ibotta
# 19           19812                                Sphere
# 20           18203  Love's Travel Stops & Country Stores
# 21           18846                     Walt Disney World
# 22           20478                            Crypto.com
# 23           17071                                PayPal
# 24           19441                                   NaN
# 25           17583                               Dialpad
# 26           18418                        Self Financial
# 27           19800                    Sun Life Financial
# 28           18306                 LiveView Technologies
# 29           20356                             Robinhood
#
#     022/2023 Revenue (millions)  022/2023 Operating Income (millions)  \
# 0                           326                                    85
# 1                           443                                    88
# 2                           367                                    -5
# 3                           269                                    35
# 4                           372                                   115
# 5                           348                                    78
# 6                           429                                    83
# 7                           348                                    71
# 8                           274                                    83
# 9                           765                                    79
# 10                          381                                   125
# 11                          263                                    68
# 12                          425                                   -12
# 13                          516                                   159
# 14                          258                                    51
# 15                          371                                   108
# 16                          329                                   -36
# 17                          259                                    47
# 18                          262                                    57
# 19                          504                                   169
# 20                          267                                    49
# 21                          261                                    66
# 22                          371                                   120
# 23                          366                                    15
# 24                          300                                    65
# 25                          289                                    36
# 26                          319                                   113
# 27                          305                                    75
# 28                          274                                    46
# 29                          323                                    85
#
#     022/2023 Player Expenses (millions)  2019 Ticket Revenue
# 0                                   159                 45.3
# 1                                   185                 72.5
# 2                                   187                 55.1
# 3                                   165                 23.7
# 4                                   158                 70.0
# 5                                   158                 67.4
# 6                                   177                 57.4
# 7                                   171                 41.6
# 8                                   132                 35.8
# 9                                   197                100.4
# 10                                  145                 66.6
# 11                                  127                 34.5
# 12                                  198                 63.9
# 13                                  177                116.8
# 14                                  132                 21.3
# 15                                  161                 75.7
# 16                                  188                 46.9
# 17                                  155                 29.5
# 18                                  154                 27.6
# 19                                  156                109.1
# 20                                  154                 52.2
# 21                                  132                 36.0
# 22                                  161                 58.7
# 23                                  179                 37.0
# 24                                  156                 52.8
# 25                                  145                 56.1
# 26                                  110                 56.3
# 27                                  156                 63.4
# 28                                  154                 42.0
# 29                                  159                 60.9

# %% [markdown]
# # Merging Datasets
#
# Merged the financials and city dataset together

# %%
# preprocessing data
#financials["City"] = financials["City"].str.lower().str.strip()

# remove any whitespace in the city names
cities["city"] = cities["city"].str.replace(" ", "")
financials["City"] = financials["City"].str.replace(" ", "")

# merged data
merged_df = pd.merge(financials, cities, left_on=["City", "State"], right_on=["city", "state_name"], how="inner")

# see what cities are not included
set(financials["City"]) - set(merged_df["City"])
# Out:
# {'Toronto'}

# %% [markdown]
# # Data Exploration

# %% [markdown]
# Distribution of Revnues, Operating Income, and Player Expense
#
# note that there are salary caps in the NBA that limits player expenses

# %%
fig, ax = plt.subplots()
counts, bins = np.histogram(financials["022/2023 Revenue (millions)"])
ax.hist(bins[:-1], bins, weights=counts)
ax.set_title("Distribution of 2022-2023 Revenues")
ax.set_xlabel("2022-2023 Revenue")
ax.set_ylabel("Number of Teams")
plt.show()

fig, ax = plt.subplots()
counts, bins = np.histogram(financials["022/2023 Operating Income (millions)"])
ax.hist(bins[:-1], bins, weights=counts)
ax.set_title("Distribution of 2022-2023 Operating Income")
ax.set_xlabel("2022-2023 Income")
ax.set_ylabel("Number of Teams")
plt.show()

fig, ax = plt.subplots()
counts, bins = np.histogram(financials["022/2023 Player Expenses (millions)"])
ax.hist(bins[:-1], bins, weights=counts)
ax.set_title("Distribution of 2022-2023 Player Expense")
ax.set_xlabel("2022-2023 Player Expense")
ax.set_ylabel("Number of Teams")
plt.show()

# %%
merged_df.columns[merged_df.isna().sum() > 0]   # check to see what columns have NA values
#merged_df[["City", "income_household_median"]]
# Out:
# Index(['Jersey Sponsor', 'city_alt', 'age_under_10', 'age_10_to_19', 'age_20s',
#        'age_30s', 'age_40s', 'age_50s', 'age_60s', 'age_70s', 'age_over_80',
#        'age_over_65', 'age_18_to_24', 'age_over_18', 'male', 'female',
#        'married', 'divorced', 'never_married', 'widowed', 'family_size',
#        'family_dual_income', 'income_household_under_5',
#        'income_household_5_to_10', 'income_household_10_to_15',
#        'income_household_15_to_20', 'income_household_20_to_25',
#        'income_household_25_to_35', 'income_household_35_to_50',
#        'income_household_50_to_75', 'income_household_75_to_100',
#        'income_household_100_to_150', 'income_household_150_over',
#        'income_household_six_figure', 'income_individual_median',
#        'home_ownership', 'housing_units', 'home_value', 'rent_median',
#        'rent_burden', 'education_less_highschool', 'education_highschool',
#        'education_some_college', 'education_bachelors', 'education_graduate',
#        'education_college_or_above', 'education_stem_degree',
#        'labor_force_participation', 'unemployment_rate', 'race_white',
#        'race_black', 'race_asian', 'race_native', 'race_pacific', 'race_other',
#        'race_multiple', 'hispanic', 'disabled', 'poverty', 'limited_english',
#        'commute_time', 'health_uninsured', 'veteran'],
#       dtype='object')

# %%
cov_matrix = merged_df.cov()
#display(cov_matrix)
display(cov_matrix.loc["022/2023 Revenue (millions)",:].tail(50))
# Out:
# /var/folders/x2/67qpprrj1yg71spwg0l_zx8c0000gn/T/ipykernel_86828/2383887409.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cov_matrix = merged_df.cov()
# divorced                      -1.238407e+02
# never_married                  5.737037e+00
# widowed                        5.411111e+00
# family_size                   -1.161852e+00
# family_dual_income             2.116296e+02
# income_household_median        1.280614e+06
# income_household_under_5      -3.528519e+01
# income_household_5_to_10      -1.718519e+01
# income_household_10_to_15     -1.887407e+01
# income_household_15_to_20     -3.456667e+01
# income_household_20_to_25     -3.294444e+01
# income_household_25_to_35     -8.600741e+01
# income_household_35_to_50     -1.515963e+02
# income_household_50_to_75     -1.733037e+02
# income_household_75_to_100    -6.451852e+01
# income_household_100_to_150    3.851852e+00
# income_household_150_over      6.123741e+02
# income_household_six_figure    6.162259e+02
# income_individual_median       4.588508e+05
# home_ownership                -4.450519e+02
# housing_units                  3.126479e+07
# home_value                     2.426292e+07
# rent_median                    2.607248e+04
# rent_burden                   -9.834444e+01
# education_less_highschool      1.580407e+02
# education_highschool          -2.018593e+02
# education_some_college        -2.709333e+02
# education_bachelors            1.797704e+02
# education_graduate             1.345593e+02
# education_college_or_above     3.143296e+02
# education_stem_degree          1.592111e+02
# labor_force_participation      2.773333e+01
# unemployment_rate             -7.788889e+00
# race_white                    -1.770444e+02
# race_black                    -7.585296e+02
# race_asian                     5.728185e+02
# race_native                   -4.622222e+00
# race_pacific                  -3.348148e+00
# race_other                     2.778852e+02
# race_multiple                  9.520741e+01
# hispanic                       4.762630e+02
# disabled                      -6.167037e+01
# poverty                       -1.284259e+02
# limited_english                3.074815e+02
# commute_time                   3.238778e+02
# health_uninsured              -8.472222e+01
# veteran                       -9.978889e+01
# cbsa_fips                      4.291475e+04
# cbsa_metro                     0.000000e+00
# csa_fips                       5.995382e+02
# Name: 022/2023 Revenue (millions), dtype: float64

# %%
for column in merged_df.columns:
    print(column)
# Out:
# City
# State
# Team Name
# Arena Sponsor
# Arena Cost (millions)
# Year of Arena Construction
# Arena Capacity
# Jersey Sponsor
# 022/2023 Revenue (millions)
# 022/2023 Operating Income (millions)
# 022/2023 Player Expenses (millions)
# 2019 Ticket Revenue
# city
# city_ascii
# city_alt
# state_id
# state_name
# county_fips
# county_name
# county_fips_all
# county_name_all
# lat
# lng
# population
# population_proper
# density
# source
# military
# incorporated
# cdp
# township
# timezone
# ranking
# zips
# id
# age_median
# age_under_10
# age_10_to_19
# age_20s
# age_30s
# age_40s
# age_50s
# age_60s
# age_70s
# age_over_80
# age_over_65
# age_18_to_24
# age_over_18
# male
# female
# married
# divorced
# never_married
# widowed
# family_size
# family_dual_income
# income_household_median
# income_household_under_5
# income_household_5_to_10
# income_household_10_to_15
# income_household_15_to_20
# income_household_20_to_25
# income_household_25_to_35
# income_household_35_to_50
# income_household_50_to_75
# income_household_75_to_100
# income_household_100_to_150
# income_household_150_over
# income_household_six_figure
# income_individual_median
# home_ownership
# housing_units
# home_value
# rent_median
# rent_burden
# education_less_highschool
# education_highschool
# education_some_college
# education_bachelors
# education_graduate
# education_college_or_above
# education_stem_degree
# labor_force_participation
# unemployment_rate
# race_white
# race_black
# race_asian
# race_native
# race_pacific
# race_other
# race_multiple
# hispanic
# disabled
# poverty
# limited_english
# commute_time
# health_uninsured
# veteran
# cbsa_fips
# cbsa_name
# cbsa_metro
# csa_fips
# csa_name

# %% [markdown]
# # Regression Analysis

# %%
X = np.log(merged_df["population"])
X = sm.add_constant(X)
y = np.log(merged_df["022/2023 Revenue (millions)"])
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
fig, ax = plt.subplots()
sns.regplot(x="population", y="022/2023 Revenue (millions)", data=merged_df, ax=ax)

X = np.log(merged_df["density"])
X = sm.add_constant(X)
y = np.log(merged_df["022/2023 Revenue (millions)"])
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
fig, ax = plt.subplots()
sns.regplot(x="density", y="022/2023 Revenue (millions)", data=merged_df, ax=ax)

X = np.log(merged_df["income_household_median"])
X = sm.add_constant(X)
y = np.log(merged_df["022/2023 Revenue (millions)"])
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
fig, ax = plt.subplots()
sns.regplot(x="income_household_median", y="022/2023 Revenue (millions)", data=merged_df, ax=ax)

X = np.log(merged_df["age_median"])
X = sm.add_constant(X)
y = np.log(merged_df["022/2023 Revenue (millions)"])
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
fig, ax = plt.subplots()
sns.regplot(x="age_median", y="022/2023 Revenue (millions)", data=merged_df, ax=ax)

X = np.log(merged_df["unemployment_rate"])
X = sm.add_constant(X)
y = np.log(merged_df["022/2023 Revenue (millions)"])
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
fig, ax = plt.subplots()
sns.regplot(x="unemployment_rate", y="022/2023 Revenue (millions)", data=merged_df, ax=ax)
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     022/2023 Revenue (millions)   R-squared:                       0.442
# Model:                                     OLS   Adj. R-squared:                  0.422
# Method:                          Least Squares   F-statistic:                     21.43
# Date:                         Sun, 31 Mar 2024   Prob (F-statistic):           8.26e-05
# Time:                                 17:24:07   Log-Likelihood:                 7.4665
# No. Observations:                           29   AIC:                            -10.93
# Df Residuals:                               27   BIC:                            -8.198
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6757      0.684      3.914      0.001       1.273       4.078
# population     0.2111      0.046      4.629      0.000       0.118       0.305
# ==============================================================================
# Omnibus:                       35.762   Durbin-Watson:                   2.504
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              114.628
# Skew:                           2.429   Prob(JB):                     1.28e-25
# Kurtosis:                      11.442   Cond. No.                         286.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     022/2023 Revenue (millions)   R-squared:                       0.427
# Model:                                     OLS   Adj. R-squared:                  0.406
# Method:                          Least Squares   F-statistic:                     20.13
# Date:                         Sun, 31 Mar 2024   Prob (F-statistic):           0.000121
# Time:                                 17:24:08   Log-Likelihood:                 7.0718
# No. Observations:                           29   AIC:                            -10.14
# Df Residuals:                               27   BIC:                            -7.409
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.3243      0.339     12.760      0.000       3.629       5.020
# density        0.1971      0.044      4.486      0.000       0.107       0.287
# ==============================================================================
# Omnibus:                        6.902   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                5.106
# Skew:                           0.834   Prob(JB):                       0.0779
# Kurtosis:                       4.201   Cond. No.                         72.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     022/2023 Revenue (millions)   R-squared:                       0.226
# Model:                                     OLS   Adj. R-squared:                  0.198
# Method:                          Least Squares   F-statistic:                     7.893
# Date:                         Sun, 31 Mar 2024   Prob (F-statistic):            0.00912
# Time:                                 17:24:08   Log-Likelihood:                 2.7139
# No. Observations:                           29   AIC:                            -1.428
# Df Residuals:                               27   BIC:                             1.307
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.8908      1.761      0.506      0.617      -2.722       4.504
# income_household_median     0.4447      0.158      2.809      0.009       0.120       0.770
# ==============================================================================
# Omnibus:                        2.270   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.321   Jarque-Bera (JB):                1.472
# Skew:                           0.301   Prob(JB):                        0.479
# Kurtosis:                       2.075   Cond. No.                         466.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     022/2023 Revenue (millions)   R-squared:                       0.147
# Model:                                     OLS   Adj. R-squared:                  0.115
# Method:                          Least Squares   F-statistic:                     4.647
# Date:                         Sun, 31 Mar 2024   Prob (F-statistic):             0.0402
# Time:                                 17:24:08   Log-Likelihood:                 1.2984
# No. Observations:                           29   AIC:                             1.403
# Df Residuals:                               27   BIC:                             4.138
# Df Model:                                    1
# Covariance Type:                     nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5009      2.940     -0.170      0.866      -6.533       5.531
# age_median     1.7806      0.826      2.156      0.040       0.086       3.475
# ==============================================================================
# Omnibus:                        2.100   Durbin-Watson:                   2.242
# Prob(Omnibus):                  0.350   Jarque-Bera (JB):                1.582
# Skew:                           0.568   Prob(JB):                        0.453
# Kurtosis:                       2.862   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# Cell In[8], line 40
#      38 X = sm.add_constant(X)
#      39 y = np.log(merged_df["022/2023 Revenue (millions)"])
# ---> 40 model = sm.OLS(y, X)
#      41 results = model.fit()
#      42 print(results.summary())
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:922, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     919     msg = ("Weights are not supported in OLS and will be ignored"
#     920            "An exception will be raised in the next version.")
#     921     warnings.warn(msg, ValueWarning)
# --> 922 super(OLS, self).__init__(endog, exog, missing=missing,
#     923                           hasconst=hasconst, **kwargs)
#     924 if "weights" in self._init_keys:
#     925     self._init_keys.remove("weights")
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:748, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     746 else:
#     747     weights = weights.squeeze()
# --> 748 super(WLS, self).__init__(endog, exog, missing=missing,
#     749                           weights=weights, hasconst=hasconst, **kwargs)
#     750 nobs = self.exog.shape[0]
#     751 weights = self.weights
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:202, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     201 def __init__(self, endog, exog, **kwargs):
# --> 202     super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     203     self.pinv_wexog: Float64Array | None = None
#     204     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/data.py:675, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     exog = np.asarray(exog)
#     674 klass = handle_data_class_factory(endog, exog)
# --> 675 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676              **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/data.py:88, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      86 self.const_idx = None
#      87 self.k_constant = 0
# ---> 88 self._handle_constant(hasconst)
#      89 self._check_integrity()
#      90 self._cache = {}
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/data.py:134, in ModelData._handle_constant(self, hasconst)
#     132 exog_max = np.max(self.exog, axis=0)
#     133 if not np.isfinite(exog_max).all():
# --> 134     raise MissingDataError('exog contains inf or nans')
#     135 exog_min = np.min(self.exog, axis=0)
#     136 const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans

# %%
# stlouis = cities[cities["city"] == "St. Louis"]
city = "St. Louis"
state_id = "MO"
stlouis = cities.query("@city == city and @state_id == state_id")   # query/select St. Louis, Missouri
display(stlouis.melt().head(50))
# Out:
#                      variable  \
# 0                        city
# 1                  city_ascii
# 2                    city_alt
# 3                    state_id
# 4                  state_name
# 5                 county_fips
# 6                 county_name
# 7             county_fips_all
# 8             county_name_all
# 9                         lat
# 10                        lng
# 11                 population
# 12          population_proper
# 13                    density
# 14                     source
# 15                   military
# 16               incorporated
# 17                        cdp
# 18                   township
# 19                   timezone
# 20                    ranking
# 21                       zips
# 22                         id
# 23                 age_median
# 24               age_under_10
# 25               age_10_to_19
# 26                    age_20s
# 27                    age_30s
# 28                    age_40s
# 29                    age_50s
# 30                    age_60s
# 31                    age_70s
# 32                age_over_80
# 33                age_over_65
# 34               age_18_to_24
# 35                age_over_18
# 36                       male
# 37                     female
# 38                    married
# 39                   divorced
# 40              never_married
# 41                    widowed
# 42                family_size
# 43         family_dual_income
# 44    income_household_median
# 45   income_household_under_5
# 46   income_household_5_to_10
# 47  income_household_10_to_15
# 48  income_household_15_to_20
# 49  income_household_20_to_25
#
#                                                 value
# 0                                           St. Louis
# 1                                           St. Louis
# 2                                         Saint Louis
# 3                                                  MO
# 4                                            Missouri
# 5                                               29510
# 6                                           St. Louis
# 7                                               29510
# 8                                           St. Louis
# 9                                             38.6359
# 10                                           -90.2451
# 11                                            2130881
# 12                                             298018
# 13                                             1864.3
# 14                                              shape
# 15                                              False
# 16                                               True
# 17                                              False
# 18                                              False
# 19                                    America/Chicago
# 20                                                  1
# 21  63110 63111 63112 63113 63115 63116 63118 6312...
# 22                                         1840001651
# 23                                               36.5
# 24                                               10.6
# 25                                               10.4
# 26                                               16.8
# 27                                               17.3
# 28                                               11.9
# 29                                               11.9
# 30                                               11.9
# 31                                                6.2
# 32                                                3.1
# 33                                               14.5
# 34                                                9.1
# 35                                               81.5
# 36                                               48.6
# 37                                               51.4
# 38                                               30.2
# 39                                               15.3
# 40                                               49.2
# 41                                                5.2
# 42                                               2.99
# 43                                               51.8
# 44                                            52941.0
# 45                                                6.0
# 46                                                3.3
# 47                                                6.8
# 48                                                5.1
# 49                                                4.1

# %%
cities.sort_values(by="population", ascending=False).head(60)
# Out:
#               city      city_ascii     city_alt state_id  \
# 0         New York        New York          NaN       NY
# 1      Los Angeles     Los Angeles          NaN       CA
# 2          Chicago         Chicago          NaN       IL
# 3            Miami           Miami          NaN       FL
# 4          Houston         Houston          NaN       TX
# 5           Dallas          Dallas          NaN       TX
# 6     Philadelphia    Philadelphia          NaN       PA
# 7          Atlanta         Atlanta          NaN       GA
# 8    Washington DC   Washington DC          NaN       DC
# 9           Boston          Boston          NaN       MA
# 10         Phoenix         Phoenix          NaN       AZ
# 11         Detroit         Detroit          NaN       MI
# 12         Seattle         Seattle          NaN       WA
# 13   San Francisco   San Francisco          NaN       CA
# 14       San Diego       San Diego          NaN       CA
# 15     Minneapolis     Minneapolis          NaN       MN
# 16           Tampa           Tampa          NaN       FL
# 17        Brooklyn        Brooklyn          NaN       NY
# 18          Denver          Denver          NaN       CO
# 19          Queens          Queens          NaN       NY
# 20       Riverside       Riverside          NaN       CA
# 21       Las Vegas       Las Vegas          NaN       NV
# 22       Baltimore       Baltimore          NaN       MD
# 23       St. Louis       St. Louis  Saint Louis       MO
# 24        Portland        Portland          NaN       OR
# 25     San Antonio     San Antonio          NaN       TX
# 26      Sacramento      Sacramento          NaN       CA
# 27          Austin          Austin          NaN       TX
# 28         Orlando         Orlando          NaN       FL
# 29        San Juan        San Juan          NaN       PR
# 30        San Jose        San Jose          NaN       CA
# 31      Pittsburgh      Pittsburgh          NaN       PA
# 32    Indianapolis    Indianapolis          NaN       IN
# 33       Manhattan       Manhattan          NaN       NY
# 34      Cincinnati      Cincinnati          NaN       OH
# 35     Kansas City     Kansas City          NaN       MO
# 36       Cleveland       Cleveland          NaN       OH
# 37        Columbus        Columbus          NaN       OH
# 38           Bronx           Bronx          NaN       NY
# 39  Virginia Beach  Virginia Beach          NaN       VA
# 40       Charlotte       Charlotte          NaN       NC
# 41       Milwaukee       Milwaukee          NaN       WI
# 42      Providence      Providence          NaN       RI
# 43    Jacksonville    Jacksonville          NaN       FL
# 44       Nashville       Nashville          NaN       TN
# 45  Salt Lake City  Salt Lake City          NaN       UT
# 46         Raleigh         Raleigh          NaN       NC
# 47        Richmond        Richmond          NaN       VA
# 48         Memphis         Memphis          NaN       TN
# 49   Oklahoma City   Oklahoma City          NaN       OK
# 50        Hartford        Hartford          NaN       CT
# 51      Louisville      Louisville          NaN       KY
# 52         Buffalo         Buffalo          NaN       NY
# 53     New Orleans     New Orleans          NaN       LA
# 54      Fort Worth      Fort Worth          NaN       TX
# 55      Bridgeport      Bridgeport          NaN       CT
# 56          Tucson          Tucson          NaN       AZ
# 57         El Paso         El Paso          NaN       TX
# 58           Omaha           Omaha          NaN       NE
# 59         McAllen         McAllen          NaN       TX
#
#               state_name  county_fips           county_name  \
# 0               New York        36081                Queens
# 1             California         6037           Los Angeles
# 2               Illinois        17031                  Cook
# 3                Florida        12086            Miami-Dade
# 4                  Texas        48201                Harris
# 5                  Texas        48113                Dallas
# 6           Pennsylvania        42101          Philadelphia
# 7                Georgia        13121                Fulton
# 8   District of Columbia        11001  District of Columbia
# 9          Massachusetts        25025               Suffolk
# 10               Arizona         4013              Maricopa
# 11              Michigan        26163                 Wayne
# 12            Washington        53033                  King
# 13            California         6075         San Francisco
# 14            California         6073             San Diego
# 15             Minnesota        27053              Hennepin
# 16               Florida        12057          Hillsborough
# 17              New York        36047                 Kings
# 18              Colorado         8031                Denver
# 19              New York        36081                Queens
# 20            California         6065             Riverside
# 21                Nevada        32003                 Clark
# 22              Maryland        24510             Baltimore
# 23              Missouri        29510             St. Louis
# 24                Oregon        41051             Multnomah
# 25                 Texas        48029                 Bexar
# 26            California         6067            Sacramento
# 27                 Texas        48453                Travis
# 28               Florida        12095                Orange
# 29           Puerto Rico        72127              San Juan
# 30            California         6085           Santa Clara
# 31          Pennsylvania        42003             Allegheny
# 32               Indiana        18097                Marion
# 33              New York        36061              New York
# 34                  Ohio        39061              Hamilton
# 35              Missouri        29095               Jackson
# 36                  Ohio        39035              Cuyahoga
# 37                  Ohio        39049              Franklin
# 38              New York        36005                 Bronx
# 39              Virginia        51810        Virginia Beach
# 40        North Carolina        37119           Mecklenburg
# 41             Wisconsin        55079             Milwaukee
# 42          Rhode Island        44007            Providence
# 43               Florida        12031                 Duval
# 44             Tennessee        47037              Davidson
# 45                  Utah        49035             Salt Lake
# 46        North Carolina        37183                  Wake
# 47              Virginia        51760              Richmond
# 48             Tennessee        47157                Shelby
# 49              Oklahoma        40109              Oklahoma
# 50           Connecticut         9110               Capitol
# 51              Kentucky        21111             Jefferson
# 52              New York        36029                  Erie
# 53             Louisiana        22071               Orleans
# 54                 Texas        48439               Tarrant
# 55           Connecticut         9120    Greater Bridgeport
# 56               Arizona         4019                  Pima
# 57                 Texas        48141               El Paso
# 58              Nebraska        31055               Douglas
# 59                 Texas        48215               Hidalgo
#
#                   county_fips_all                        county_name_all  \
# 0   36081|36047|36085|36005|36061   Queens|Kings|Richmond|Bronx|New York
# 1                            6037                            Los Angeles
# 2                     17031|17043                            Cook|DuPage
# 3                           12086                             Miami-Dade
# 4               48201|48157|48339            Harris|Fort Bend|Montgomery
# 5   48113|48397|48085|48257|48121  Dallas|Rockwall|Collin|Kaufman|Denton
# 6                           42101                           Philadelphia
# 7                     13121|13089                          Fulton|DeKalb
# 8                           11001                   District of Columbia
# 9                           25025                                Suffolk
# 10                           4013                               Maricopa
# 11                          26163                                  Wayne
# 12                          53033                                   King
# 13                           6075                          San Francisco
# 14                           6073                              San Diego
# 15                          27053                               Hennepin
# 16                          12057                           Hillsborough
# 17                          36047                                  Kings
# 18                           8031                                 Denver
# 19                          36081                                 Queens
# 20                           6065                              Riverside
# 21                          32003                                  Clark
# 22                          24510                              Baltimore
# 23                          29510                              St. Louis
# 24              41051|41005|41067         Multnomah|Clackamas|Washington
# 25                    48029|48325                           Bexar|Medina
# 26                           6067                             Sacramento
# 27              48453|48491|48209                 Travis|Williamson|Hays
# 28                          12095                                 Orange
# 29                          72127                               San Juan
# 30                           6085                            Santa Clara
# 31                          42003                              Allegheny
# 32                          18097                                 Marion
# 33                          36061                               New York
# 34                          39061                               Hamilton
# 35        29095|29047|29165|29037               Jackson|Clay|Platte|Cass
# 36                          39035                               Cuyahoga
# 37              39049|39041|39045            Franklin|Delaware|Fairfield
# 38                          36005                                  Bronx
# 39                          51810                         Virginia Beach
# 40                          37119                            Mecklenburg
# 41                          55079                              Milwaukee
# 42                          44007                             Providence
# 43                          12031                                  Duval
# 44                          47037                               Davidson
# 45                          49035                              Salt Lake
# 46                    37183|37063                            Wake|Durham
# 47                          51760                               Richmond
# 48                          47157                                 Shelby
# 49              40109|40017|40027            Oklahoma|Canadian|Cleveland
# 50                           9110                                Capitol
# 51                          21111                              Jefferson
# 52                          36029                                   Erie
# 53                          22071                                Orleans
# 54        48439|48121|48367|48497             Tarrant|Denton|Parker|Wise
# 55                           9120                     Greater Bridgeport
# 56                           4019                                   Pima
# 57                          48141                                El Paso
# 58                          31055                                Douglas
# 59                          48215                                Hidalgo
#
#         lat  ...  poverty  limited_english  commute_time  health_uninsured  \
# 0   40.6943  ...     17.2             13.9          41.1               6.7
# 1   34.1141  ...     16.6             13.7          31.3              10.6
# 2   41.8375  ...     16.9              7.9          34.1               9.8
# 3   25.7840  ...     20.0             29.9          28.2              19.0
# 4   29.7860  ...     19.6             13.5          27.4              24.2
# 5   32.7935  ...     17.5              9.3          26.4              23.5
# 6   40.0077  ...     22.7              6.9          32.8               7.3
# 7   33.7628  ...     17.7              2.0          27.5              10.8
# 8   38.9047  ...     15.1              3.1          30.5               3.4
# 9   42.3188  ...     17.5             11.2          30.6               3.3
# 10  33.5722  ...     14.6              5.2          25.7              14.8
# 11  42.3834  ...     31.5              2.3          25.7               7.6
# 12  47.6211  ...     10.1              4.8          27.2               4.5
# 13  37.7558  ...     10.5             10.9          31.8               3.6
# 14  32.8313  ...     11.4              6.6          24.0               6.9
# 15  44.9635  ...     16.8              4.5          22.9               6.0
# 16  27.9945  ...     16.8              7.2          24.8              11.2
# 17  40.6501  ...      NaN              NaN           NaN               NaN
# 18  39.7620  ...     11.7              3.4          25.3               9.1
# 19  40.7498  ...      NaN              NaN           NaN               NaN
# 20  33.9381  ...     12.8              6.7          31.3               9.2
# 21  36.2333  ...     14.7              6.4          25.9              13.1
# 22  39.3051  ...     19.6              2.0          30.1               5.5
# 23  38.6359  ...     20.2              1.8          23.0              10.1
# 24  45.5371  ...     12.2              3.1          24.8               5.7
# 25  29.4632  ...     17.7              7.6          24.5              17.7
# 26  38.5677  ...     14.8              6.4          25.4               5.5
# 27  30.3005  ...     12.4              5.6          24.1              12.8
# 28  28.4773  ...     15.2              9.5          26.9              13.9
# 29  18.3985  ...      NaN             59.7          25.2               8.8
# 30  37.3012  ...      7.9             12.2          28.8               5.0
# 31  40.4397  ...     19.4              2.1          23.4               5.4
# 32  39.7771  ...     15.9              3.3          24.0               9.4
# 33  40.7834  ...      NaN              NaN           NaN               NaN
# 34  39.1413  ...     24.8              2.1          23.4               7.5
# 35  39.1238  ...     14.9              2.3          22.0              11.7
# 36  41.4764  ...     31.2              3.8          23.3               7.5
# 37  39.9862  ...     18.1              3.3          22.0               9.4
# 38  40.8501  ...      NaN              NaN           NaN               NaN
# 39  36.7335  ...      8.0              2.0          23.5               6.9
# 40  35.2083  ...     11.7              5.2          25.2              12.7
# 41  43.0642  ...     23.9              4.3          22.2               9.4
# 42  41.8230  ...     21.3             14.4          24.2               6.8
# 43  30.3322  ...     14.8              3.6          24.4              11.9
# 44  36.1715  ...     14.5              4.8          24.8              12.4
# 45  40.7776  ...     14.1              3.8          19.7              11.5
# 46  35.8324  ...     11.8              2.6          23.7              10.2
# 47  37.5295  ...     19.5              2.6          22.0               9.6
# 48  35.1087  ...     23.6              1.9          21.6              14.4
# 49  35.4676  ...     15.0              3.9          22.0              14.2
# 50  41.7661  ...     26.9             15.2          22.1               9.5
# 51  38.1663  ...     15.6              3.3          22.6               5.6
# 52  42.9018  ...     27.2              4.5          19.6               4.0
# 53  30.0687  ...     22.9              1.4          23.4               8.5
# 54  32.7817  ...     13.4              5.9          27.0              19.2
# 55  41.1918  ...     22.9             15.5          28.9              13.0
# 56  32.1541  ...     19.6              5.0          22.3              11.4
# 57  31.8476  ...     18.9             18.6          23.7              20.9
# 58  41.2627  ...     12.5              3.1          19.3              10.1
# 59  26.2252  ...     21.0             17.7          21.4              26.9
#
#    veteran  cbsa_fips                                       cbsa_name  \
# 0      2.0      35620           New York-Newark-Jersey City, NY-NJ-PA
# 1      2.3      31080              Los Angeles-Long Beach-Anaheim, CA
# 2      2.9      16980              Chicago-Naperville-Elgin, IL-IN-WI
# 3      2.0      33100         Miami-Fort Lauderdale-Pompano Beach, FL
# 4      3.6      26420            Houston-The Woodlands-Sugar Land, TX
# 5      3.8      19100                 Dallas-Fort Worth-Arlington, TX
# 6      4.2      37980     Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 7      4.3      12060            Atlanta-Sandy Springs-Alpharetta, GA
# 8      4.0      47900    Washington-Arlington-Alexandria, DC-VA-MD-WV
# 9      2.4      14460                  Boston-Cambridge-Newton, MA-NH
# 10     5.5      38060                       Phoenix-Mesa-Chandler, AZ
# 11     4.7      19820                     Detroit-Warren-Dearborn, MI
# 12     3.8      42660                     Seattle-Tacoma-Bellevue, WA
# 13     2.7      41860              San Francisco-Oakland-Berkeley, CA
# 14     7.0      41740              San Diego-Chula Vista-Carlsbad, CA
# 15     3.5      33460         Minneapolis-St. Paul-Bloomington, MN-WI
# 16     6.4      45300             Tampa-St. Petersburg-Clearwater, FL
# 17     NaN      35620           New York-Newark-Jersey City, NY-NJ-PA
# 18     4.9      19740                      Denver-Aurora-Lakewood, CO
# 19     NaN      35620           New York-Newark-Jersey City, NY-NJ-PA
# 20     4.2      40140            Riverside-San Bernardino-Ontario, CA
# 21     8.2      29820                Las Vegas-Henderson-Paradise, NV
# 22     5.3      12580                   Baltimore-Columbia-Towson, MD
# 23     5.9      41180                                St. Louis, MO-IL
# 24     4.8      38900             Portland-Vancouver-Hillsboro, OR-WA
# 25     8.2      41700                   San Antonio-New Braunfels, TX
# 26     5.0      40900                 Sacramento-Roseville-Folsom, CA
# 27     4.2      12420                Austin-Round Rock-Georgetown, TX
# 28     4.7      36740                   Orlando-Kissimmee-Sanford, FL
# 29     2.6      41980                     San Juan-Bayamón-Caguas, PR
# 30     2.8      41940              San Jose-Sunnyvale-Santa Clara, CA
# 31     4.7      38300                                  Pittsburgh, PA
# 32     5.9      26900                Indianapolis-Carmel-Anderson, IN
# 33     NaN      35620           New York-Newark-Jersey City, NY-NJ-PA
# 34     5.0      17140                            Cincinnati, OH-KY-IN
# 35     6.0      28140                              Kansas City, MO-KS
# 36     5.8      17460                            Cleveland-Elyria, OH
# 37     5.3      18140                                    Columbus, OH
# 38     NaN      35620           New York-Newark-Jersey City, NY-NJ-PA
# 39    16.6      47260      Virginia Beach-Norfolk-Newport News, VA-NC
# 40     5.2      16740               Charlotte-Concord-Gastonia, NC-SC
# 41     3.9      33340                          Milwaukee-Waukesha, WI
# 42     2.4      39300                       Providence-Warwick, RI-MA
# 43    10.9      27260                                Jacksonville, FL
# 44     4.8      34980  Nashville-Davidson--Murfreesboro--Franklin, TN
# 45     4.2      41620                              Salt Lake City, UT
# 46     4.9      39580                                Raleigh-Cary, NC
# 47     5.6      40060                                    Richmond, VA
# 48     5.8      32820                               Memphis, TN-MS-AR
# 49     8.1      36420                               Oklahoma City, OK
# 50     2.0      25540           Hartford-East Hartford-Middletown, CT
# 51     6.6      31140              Louisville/Jefferson County, KY-IN
# 52     5.2      15380                         Buffalo-Cheektowaga, NY
# 53     5.0      35380                        New Orleans-Metairie, LA
# 54     6.3      19100                 Dallas-Fort Worth-Arlington, TX
# 55     2.5      14860                 Bridgeport-Stamford-Norwalk, CT
# 56     8.2      46060                                      Tucson, AZ
# 57     8.3      21340                                     El Paso, TX
# 58     6.5      36540                     Omaha-Council Bluffs, NE-IA
# 59     3.5      32580                    McAllen-Edinburg-Mission, TX
#
#     cbsa_metro  csa_fips                                           csa_name
# 0         True     408.0                       New York-Newark, NY-NJ-CT-PA
# 1         True     348.0                         Los Angeles-Long Beach, CA
# 2         True     176.0                       Chicago-Naperville, IL-IN-WI
# 3         True     370.0           Miami-Port St. Lucie-Fort Lauderdale, FL
# 4         True     288.0                          Houston-The Woodlands, TX
# 5         True     206.0                           Dallas-Fort Worth, TX-OK
# 6         True     428.0           Philadelphia-Reading-Camden, PA-NJ-DE-MD
# 7         True     122.0  Atlanta--Athens-Clarke County--Sandy Springs, ...
# 8         True     548.0     Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# 9         True     148.0           Boston-Worcester-Providence, MA-RI-NH-CT
# 10        True     429.0                                   Phoenix-Mesa, AZ
# 11        True     220.0                       Detroit-Warren-Ann Arbor, MI
# 12        True     500.0                                 Seattle-Tacoma, WA
# 13        True     488.0                 San Jose-San Francisco-Oakland, CA
# 14        True       NaN                                                NaN
# 15        True     378.0                        Minneapolis-St. Paul, MN-WI
# 16        True       NaN                                                NaN
# 17        True     408.0                       New York-Newark, NY-NJ-CT-PA
# 18        True     216.0                                  Denver-Aurora, CO
# 19        True     408.0                       New York-Newark, NY-NJ-CT-PA
# 20        True     348.0                         Los Angeles-Long Beach, CA
# 21        True     332.0                            Las Vegas-Henderson, NV
# 22        True     548.0     Washington-Baltimore-Arlington, DC-MD-VA-WV-PA
# 23        True     476.0            St. Louis-St. Charles-Farmington, MO-IL
# 24        True     440.0                    Portland-Vancouver-Salem, OR-WA
# 25        True     484.0             San Antonio-New Braunfels-Pearsall, TX
# 26        True     472.0                           Sacramento-Roseville, CA
# 27        True       NaN                                                NaN
# 28        True     422.0                       Orlando-Lakeland-Deltona, FL
# 29        True     490.0                               San Juan-Bayamón, PR
# 30        True     488.0                 San Jose-San Francisco-Oakland, CA
# 31        True     430.0            Pittsburgh-New Castle-Weirton, PA-OH-WV
# 32        True     294.0                     Indianapolis-Carmel-Muncie, IN
# 33        True     408.0                       New York-Newark, NY-NJ-CT-PA
# 34        True     178.0          Cincinnati-Wilmington-Maysville, OH-KY-IN
# 35        True     312.0       Kansas City-Overland Park-Kansas City, MO-KS
# 36        True     184.0                         Cleveland-Akron-Canton, OH
# 37        True     198.0                     Columbus-Marion-Zanesville, OH
# 38        True     408.0                       New York-Newark, NY-NJ-CT-PA
# 39        True     545.0                      Virginia Beach-Norfolk, VA-NC
# 40        True     172.0                           Charlotte-Concord, NC-SC
# 41        True     376.0                      Milwaukee-Racine-Waukesha, WI
# 42        True     148.0           Boston-Worcester-Providence, MA-RI-NH-CT
# 43        True     300.0              Jacksonville-St. Marys-Palatka, FL-GA
# 44        True     400.0               Nashville-Davidson--Murfreesboro, TN
# 45        True     482.0                      Salt Lake City-Provo-Orem, UT
# 46        True     450.0                            Raleigh-Durham-Cary, NC
# 47        True       NaN                                                NaN
# 48        True     368.0                     Memphis-Forrest City, TN-MS-AR
# 49        True     416.0                          Oklahoma City-Shawnee, OK
# 50        True     278.0                         Hartford-East Hartford, CT
# 51        True     350.0  Louisville/Jefferson County--Elizabethtown--Ba...
# 52        True     160.0                      Buffalo-Cheektowaga-Olean, NY
# 53        True     406.0                New Orleans-Metairie-Hammond, LA-MS
# 54        True     206.0                           Dallas-Fort Worth, TX-OK
# 55        True     408.0                       New York-Newark, NY-NJ-CT-PA
# 56        True     536.0                                 Tucson-Nogales, AZ
# 57        True     238.0                          El Paso-Las Cruces, TX-NM
# 58        True     420.0                Omaha-Council Bluffs-Fremont, NE-IA
# 59        True     365.0                               McAllen-Edinburg, TX
#
# [60 rows x 91 columns]
