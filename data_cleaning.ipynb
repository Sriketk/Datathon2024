# %%
import pandas as pd
import numpy as np

# %%
financials = pd.read_excel('Given_Data/NBA_financial_data.xlsx')
financials.head()
# Out:
#         City           State          Team Name    Arena Sponsor  \
# 0    Atlanta         Georgia      Atlanta Hawks       State Farm
# 1     Boston   Massachusetts     Boston Celtics          TD Bank
# 2   Brooklyn        New York      Brooklyn Nets    Barclays Bank
# 3  Charlotte  North Carolina  Charlotte Hornets         Spectrum
# 4    Chicago        Illinois      Chicago Bulls  United Airlines
#
#    Arena Cost (millions)  Year of Arena Construction  Arena Capacity  \
# 0                  213.5                        1999           16600
# 1                  160.0                        1995           19156
# 2                 1000.0                        2012           17732
# 3                  260.0                        2005           19077
# 4                  175.0                        1994           20917
#
#   Jersey Sponsor  022/2023 Revenue (millions)  \
# 0           YMCA                          326
# 1     Vistaprint                          443
# ...

# %%
financials.columns
# Out:
# Index(['City', 'State', 'Team Name', 'Arena Sponsor', 'Arena Cost (millions)',
#        'Year of Arena Construction', 'Arena Capacity', 'Jersey Sponsor',
#        '022/2023 Revenue (millions)', '022/2023 Operating Income (millions)',
#        '022/2023 Player Expenses (millions)', '2019 Ticket Revenue'],
#       dtype='object')
